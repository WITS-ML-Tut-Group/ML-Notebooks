# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define 2 2D Guassian distributions

# Class 0
x = [[], []]

x[0] = np.random.normal(-1, 1, 20)
x[1] = np.random.normal(1, 1, 20)
class0_points = np.array(x)

#Class 1
y = [[], []]

y[0] = np.random.normal(1, 1, 20)
y[1] = np.random.normal(-1, 1, 20)
class1_points = np.array(y)


print("Class 0")
print(class0_points)
print("Class 1")
print(class1_points)
# Out:
# Class 0
# [[-1.02160069 -1.86740983 -1.35731485  0.87396733 -0.27545884 -0.17527758
#   -2.32595129 -0.3476473  -0.72281706 -0.73096477 -1.04414241 -0.19082683
#   -1.44929045 -1.17473995 -0.8562446  -2.9262457  -0.80618775 -0.67359853
#   -2.08024846  0.0292728 ]
#  [ 0.7321788   0.54358564  1.98210801  0.69756187  0.81517093  1.87198174
#    1.42908431 -0.25486144  1.78111189  1.82713602  1.67644186  1.11766763
#    1.63528307 -0.89434975 -0.05202202  1.29003436  0.4077695   0.89047945
#    1.08763326  1.18386229]]
# Class 1
# [[ 0.16576878  1.1916134   2.87958305 -0.08958241  0.75970881  1.3093776
#    0.73660425  0.75393436  1.00631457  0.25499429  1.05570792  1.0699238
#    1.18832213  0.85863235  1.19114246  1.96994939 -0.00517805  1.48285803
#   -0.47030059  1.52469678]
#  [-0.44945801 -0.69679509 -0.87725575 -0.27631901 -0.77386611 -1.86983781
#   -2.55341908 -0.16930655  0.0662724  -1.49305332 -0.89474511 -0.78918992
#   -1.03567581 -2.9330349   0.29894388  0.03293949 -1.04408162  0.32944454
#   -0.57311955 -1.51455429]]

# %%
# Plot distributions

plt.scatter(class0_points[0], class0_points[1])

plt.scatter(class1_points[0], class1_points[1])

plt.axis('equal')
plt.show()

# %%
# Question 1c var = 3 so std = 1.7

# Class 0
x = [[], []]

x[0] = np.random.normal(-1, 1.7, 20)
x[1] = np.random.normal(1, 1.7, 20)

#Class 1
y = [[], []]

y[0] = np.random.normal(1, 1.7, 20)
y[1] = np.random.normal(-1, 1.7, 20)

# Plot distributions

plt.scatter(x[0], x[1])
plt.scatter(y[0], y[1])

plt.axis('equal')
plt.show()

# %%
# Question 1d (var = 10 so std = 3) 

# Class 0
x = [[], []]

x[0] = np.random.normal(-1, 3, 20)
x[1] = np.random.normal(1, 3, 20)

#Class 1
y = [[], []]

y[0] = np.random.normal(1, 3, 20)
y[1] = np.random.normal(-1, 3, 20)

# Plot distributions

plt.scatter(x[0], x[1])
plt.scatter(y[0], y[1])

plt.axis('equal')
plt.show()

# %%
# Question 1d (var = 25 so std = 5) (center at (2,2) and (-2, -2)) 

# Class 0
x = [[], []]

x[0] = np.random.normal(-2, 5, 20)
x[1] = np.random.normal(-2, 5, 20)

#Class 1
y = [[], []]

y[0] = np.random.normal(2, 5, 20)
y[1] = np.random.normal(2, 5, 20)

# Plot distributions

plt.scatter(x[0], x[1])
plt.scatter(y[0], y[1])

plt.axis('equal')
plt.show()

# %%
# Question 1d (var = 1 so std = 1) (center at (3, 3) and (-3, -3)) 

# Class 0
x = [[], []]

x[0] = np.random.normal(-3, 1, 20)
x[1] = np.random.normal(-3, 1, 20)

#Class 1
y = [[], []]

y[0] = np.random.normal(3, 1, 20)
y[1] = np.random.normal(3, 1, 20)

# Plot distributions

plt.scatter(x[0], x[1])
plt.scatter(y[0], y[1])

plt.axis('equal')
plt.show()

# %%
#Question 2(a)

theta = np.random.uniform(-0.5,0.5,3) #Initialising random theta values
print(theta)
    
x = np.linspace(-6,6,100)
y = -theta[1]/theta[2]*x - theta[0]/theta[2] #Initialising first iteration decision boundary
plt.plot(x, y)

plt.scatter(class0_points[0], class0_points[1])

plt.scatter(class1_points[0], class1_points[1])

plt.axis('equal')
plt.show()
# Out:
# [ 0.23203237 -0.39717391  0.29061456]

# %%
#Question 2(b)

def sigmoid(x): #Sigmoid function
    return 1/(1+np.exp(-x))

def prediction(theta, x): #Intermediate function
    return(sigmoid(np.dot(theta,x)))

sum = 0
correctTotal0 = 0
correctTotal1 = 0

for i in range(20): #Calculating log likelehood for class 0
    x = [1,class0_points[0][i],class0_points[1][i]]
    sum = sum + np.log(1-prediction(theta, x))
    predictedValue = round(prediction(theta, x),0)
    if(predictedValue == 0):
        correctTotal0 += 1
    
for i in range(20): #Calculating log likelehood for class 1
    x = [1,class1_points[0][i],class1_points[1][i]]
    sum = sum + np.log(prediction(theta, x))
    predictedValue = round(prediction(theta, x),0)
    if(predictedValue == 1):
        correctTotal1 += 1
        
#Printing out confusion matrix
    
print("Classes :  0      1")
print("     0    ",correctTotal0,"   ",20-correctTotal0)
print("     1    ",correctTotal1,"   ",20-correctTotal1)
print("")

sum = sum*-1
print(sum) # Printing out log likelihood
# Out:
# Classes :  0      1
#      0     0     20
#      1     3     17
#
# 43.6726884912146

# %%
# Question 2(c)

# -----------------------------------------------------

# If true value of point is in class 0:

# i runs in forloop from 0 through 19
# x = [1,class0_points[0][i],class0_points[1][i]]

# theta[0] = theta[0] - 0.01*(0 - prediction(theta,x))
# theta[1] = theta[1] - 0.01*(0 - prediction(theta,x))*x[1]
# theta[2] = theta[2] - 0.01*(0 - prediction(theta,x))*x[2]

# -----------------------------------------------------

# If true value of point is in class 1:

# i runs in forloop from 0 through 19
# x = [1,class1_points[0][i],class1_points[1][i]]

# theta[0] = theta[0] - 0.01*(1 - prediction(theta,x))
# theta[1] = theta[1] - 0.01*(1 - prediction(theta,x))*x[1]
# theta[2] = theta[2] - 0.01*(1 - prediction(theta,x))*x[2]

# -----------------------------------------------------

# Question 2(d)

# -----------------------------------------------------
# Refer to calculations done by hand
# Calculations to confirm :

theta = [0.11,-0.45,0.01]

x = [1,0.84,0.88]

theta[0] = theta[0] - 0.01*(0 - prediction(theta,x))
theta[1] = theta[1] - 0.01*(0 - prediction(theta,x))*x[1]
theta[2] = theta[2] - 0.01*(0 - prediction(theta,x))*x[2]

print(theta)

theta[0] = theta[0] - 0.01*(1 - prediction(theta,x))
theta[1] = theta[1] - 0.01*(1 - prediction(theta,x))*x[1]
theta[2] = theta[2] - 0.01*(1 - prediction(theta,x))*x[2]
# Out:
# [0.11435560376075814, -0.4463322954885108, 0.013849027453423972]

# %%
# Question 2E

#train for class 0
print(theta)
for i in range(20):
    x = [1,class0_points[0][i],class0_points[1][i]]
    theta[0] = theta[0] - 0.01*(0 - prediction(theta,x))
    theta[1] = theta[1] - 0.01*(0 - prediction(theta,x))*x[1]
    theta[2] = theta[2] - 0.01*(0- prediction(theta,x))*x[2]
print(theta)
##train for class 1
for i in range(20):
    x = [1,class1_points[0][i],class1_points[1][i]]
    theta[0] = theta[0] - 0.01*(1 - prediction(theta,x))
    theta[1] = theta[1] - 0.01*(1 - prediction(theta,x))*x[1]
    theta[2] = theta[2] - 0.01*(1- prediction(theta,x))*x[2]
print(theta)
# Out:
# [0.10873783543597032, -0.45106283404196446, 0.008884624785404157]
# [0.2420200199151476, -0.5948995623923284, 0.14417320689659496]
# [0.11424932298115803, -0.7303535641014494, 0.259930888511956]

# %%
x = np.linspace(-6,6,100)
y = -theta[1]/theta[2]*x - theta[0]/theta[2] #Initialising first iteration decision boundary
print(theta)
plt.plot(x, y)

plt.scatter(class0_points[0], class0_points[1])

plt.scatter(class1_points[0], class1_points[1])

plt.axis('equal')
plt.show()
# Out:
# [0.11424932298115803, -0.7303535641014494, 0.259930888511956]

# %%
## error of current model

sum = 0
correctTotal0 = 0
correctTotal1 = 0

for i in range(20): #Calculating log likelehood for class 0
    x = [1,class0_points[0][i],class0_points[1][i]]
    sum = sum + np.log(1-prediction(theta,x))
    predictedValue = round(prediction(theta,x),0)
    if(predictedValue == 0):
        correctTotal0 += 1
    
for i in range(20): #Calculating log likelehood for class 1
    x = [1,class1_points[0][i],class1_points[1][i]]
    sum = sum + np.log(prediction(theta,x))
    predictedValue = round(prediction(theta,x),0)
    if(predictedValue == 1):
        correctTotal1 += 1
        
#Printing out confusion matrix
print("Classes :  0      1")
print("     0    ",correctTotal0,"   ",20-correctTotal0)
print("     1    ",correctTotal1,"   ",20-correctTotal1)
print("")
 

sum = sum*-1
print(sum) #
# Out:
# Classes :  0      1
#      0     1     19
#      1     2     18
#
# 52.1893139392679

# %%
def diff(new,old):
    finish = [0,0,0]
    for i in range(3):
        finish[i] = abs(new[i] - old[i])
    sum= finish[0] + finish[1] + finish[2]
    return sum 

def myprediction(theta,x):
    return(sigmoid(np.dot(theta,x)))
    

condition = True
count = 0
newtheta = [0,0,0]
while condition == True and count < 1000:
    
    for i in range(20):
        
        newtheta = [theta[0],theta[1],theta[2]]
        x = [1,class0_points[0][i],class0_points[1][i]]
        newtheta[0] = newtheta[0] + 0 - myprediction(newtheta,x)
        newtheta[1] = newtheta[1] + 0.01*(0 - myprediction(newtheta,x))*x[1]
        newtheta[2] = newtheta[2] + 0.01*(0- myprediction(newtheta,x))*x[2]
        count = count +1
        con = diff(newtheta,theta)
        print("this is con ")
        print(con)
        if(con < 0.05):
            condition = False
            break
        theta = [newtheta[0],newtheta[1],newtheta[2]]
    ##train for class 1
    for i in range(20):
        newtheta = [theta[0],theta[1],theta[2]]
        x = [1,class1_points[0][i],class1_points[1][i]]
        newtheta[0] = newtheta[0] + 1 - myprediction(newtheta,x)
        newtheta[1] = newtheta[1] + 0.01*(1 - myprediction(newtheta,x))*x[1]
        newtheta[2] = newtheta[2] + 0.01*(1- myprediction(newtheta,x))*x[2]
        count = count +1
        con = diff(newtheta,theta)
        print("this is conn")
        print(con)
        if(con < 0.05):
            condition = False
            break
        theta = [newtheta[0],newtheta[1],newtheta[2]]
# Out:
# this is con
# 0.7510139372415273
# this is con
# 0.7167487834340451
# this is con
# 0.5484287505314264
# this is con
# 0.091256989002416
# this is con
# 0.17517179008777464
# this is con
# 0.1782405551173667
# this is con
# 0.4348043476947392
# this is con
# 0.07331122671279436
# this is con
# 0.13618650802668575
# this is con
# 0.12259745202549838
# this is con
# 0.12940489707824457
# this is con
# 0.0586459469444377
# this is con
# 0.1395752529840329
# this is con
# 0.06080923570819394
# this is con
# 0.055230432212721475
# this is con
# 0.24726760144613238
# this is con
# 0.044520471962522734
# this is conn
# 0.9868046136255401
# this is conn
# 0.9940539218803681
# this is conn
# 1.0158975346993873
# this is conn
# 0.6891957504416846
# this is conn
# 0.6878966571977215
# this is conn
# 0.6710927426866238
# this is conn
# 0.4427944536911065
# this is conn
# 0.24149003969936428
# this is conn
# 0.21984638368848175
# this is conn
# 0.15831315180687994
# this is conn
# 0.19333879539282203
# this is conn
# 0.16342653481809802
# this is conn
# 0.15788608452353467
# this is conn
# 0.1560149511579186
# this is conn
# 0.09748144755994392
# this is conn
# 0.14385192020798784
# this is conn
# 0.0480815971543076

# %%
##plot decision boundry

# %%
##training error
sum = 0
correctTotal0 = 0
correctTotal1 = 0

for i in range(20): #Calculating log likelehood for class 0
    x = [1,class0_points[0][i],class0_points[1][i]]
    sum = sum + np.log(1-prediction(x))
    predictedValue = round(prediction(x),0)
    if(predictedValue == 0):
        correctTotal0 += 1
    
for i in range(20): #Calculating log likelehood for class 1
    x = [1,class1_points[0][i],class1_points[1][i]]
    sum = sum + np.log(prediction((x)))
    predictedValue = round(prediction(x),0)
    if(predictedValue == 1):
        correctTotal1 += 1
        
#Printing out confusion matrix
    
print("Classes :  0      1")
print("     0    ",correctTotal0,"   ",20-correctTotal0)
print("     1    ",correctTotal1,"   ",20-correctTotal1)
print("")

sum = sum*-1
print(sum) # Printing out log likelihood
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-2510acba4e7f> in <module>
#       6 for i in range(20): #Calculating log likelehood for class 0
#       7     x = [1,class0_points[0][i],class0_points[1][i]]
# ----> 8     sum = sum + np.log(1-prediction(x))
#       9     predictedValue = round(prediction(x),0)
#      10     if(predictedValue == 0):
#
# TypeError: prediction() missing 1 required positional argument: 'x'
