# %%
# %%capture
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ipynb.fs.full.CleaningData import getDataset
from IPython.display import FileLink, FileLinks
from IPython.display import display, Markdown
from ipynb.fs.full.CleaningData import getCovarianceVector

import warnings
warnings.filterwarnings('ignore')

pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", None)

# %%
# %%capture
df = getDataset(500)

# %%
df.head(10)
# Out:
#    length_url  length_hostname        ip   nb_dots  nb_hyphens     nb_qm  \
# 0   -0.267694        -0.106208 -0.416451  0.354323   -0.489240  2.348593
# 1    1.176075         9.298228 -0.416451  5.278392   -0.489240 -0.385281
# 2   -0.162053         0.364013 -0.416451  0.354323   -0.489240 -0.385281
# 3   -0.707868        -0.764519 -0.416451 -0.349115   -0.489240 -0.385281
# 4   -0.584619        -0.200253 -0.416451 -0.349115   -0.489240 -0.385281
# 5    1.176075         2.715122  2.401034  1.057762    0.005168  2.348593
# 6   -0.197266        -0.576430 -0.416451 -0.349115   -0.489240  2.348593
# 7   -0.179659        -0.670475 -0.416451  1.761200   -0.489240 -0.385281
# 8   -0.461371         0.081880 -0.416451 -0.349115   -0.489240 -0.385281
# 9   -0.690261        -0.576430 -0.416451 -0.349115   -0.489240 -0.385281
#
#      nb_and     nb_eq  nb_underscore  nb_slash  nb_colon    nb_www    nb_com  \
# 0 -0.193945  0.673490      -0.286618 -0.681912 -0.114715  1.089491 -0.336884
# 1 -0.193945 -0.287765      -0.286618 -0.681912 -0.114715 -0.898817 -0.336884
# 2 -0.193945 -0.287765      -0.286618 -0.157880 -0.114715  1.089491 -0.336884
# 3 -0.193945 -0.287765      -0.286618 -0.681912 -0.114715  1.089491 -0.336884
# 4 -0.193945 -0.287765      -0.286618 -0.681912 -0.114715  1.089491 -0.336884
# 5  2.101608  2.596000       1.429054  0.366151 -0.114715 -0.898817  2.292462
# 6 -0.193945  0.673490      -0.286618  0.366151 -0.114715  1.089491 -0.336884
# 7 -0.193945 -0.287765      -0.286618 -0.157880 -0.114715 -0.898817  2.292462
# 8 -0.193945 -0.287765      -0.286618 -0.157880 -0.114715  1.089491 -0.336884
# 9 -0.193945 -0.287765      -0.286618 -1.205944 -0.114715  1.089491 -0.336884
#
#    https_token  ratio_digits_url  ratio_digits_host  tld_in_path  \
# 0     0.795523          0.628576          -0.268336    -0.264734
# 1     0.795523          0.021465           0.348035    -0.264734
# 2     0.795523         -0.593281          -0.268336    -0.264734
# 3     0.795523          1.012588           2.170055    -0.264734
# 4    -1.256926         -0.593281          -0.268336    -0.264734
# 5    -1.256926          0.724033          -0.268336    -0.264734
# 6    -1.256926         -0.593281          -0.268336    -0.264734
# 7     0.795523         -0.593281          -0.268336    -0.264734
# 8     0.795523         -0.593281          -0.268336    -0.264734
# 9     0.795523         -0.593281          -0.268336    -0.264734
#
#    tld_in_subdomain  nb_subdomains  prefix_suffix  random_domain  \
# 0         -0.231700       1.195367      -0.502943      -0.298956
# 1         -0.231700       1.195367      -0.502943      -0.298956
# 2         -0.231700       1.195367      -0.502943      -0.298956
# 3         -0.231700      -0.378668      -0.502943       3.344686
# 4         -0.231700      -0.378668      -0.502943      -0.298956
# 5          4.315555       1.195367       1.988123      -0.298956
# 6         -0.231700      -0.378668      -0.502943      -0.298956
# 7         -0.231700       1.195367      -0.502943      -0.298956
# 0        -0.405773   -0.260947          1.132628       0.523444
# 1        -0.405773   -0.260947         -0.882825      -1.253139
# 2        -0.405773   -0.260947         -0.882825       1.150474
# 3        -0.405773   -0.260947         -0.882825       1.150474
# 4        -0.405773   -0.260947          1.132628       0.082201
# 5        -0.405773   -0.260947         -0.882825       1.150474
# 6        -0.405773   -0.260947         -0.882825      -1.253139
# 7        -0.405773   -0.260947         -0.882825       1.150474
# 8         0.503233   -0.260947         -0.882825       0.349269
# 9         0.705234   -0.260947          1.132628      -1.253139
#
#    ratio_intMedia  ratio_extMedia  safe_anchor  empty_title  domain_in_title  \
# 0        1.242228       -0.596423     1.044103    -0.378681         0.540780
# 1       -0.920043       -0.596423    -0.948371     2.640513         0.540780
# 2       -0.920043       -0.596423    -0.948371    -0.378681         0.540780
# 3        1.075899       -0.394366     1.166092    -0.378681         0.540780
# 4        0.161093        0.716949     1.128726    -0.378681        -1.849019
# 5        1.242228       -0.596423     1.613382    -0.378681         0.540780
# 6       -0.920043       -0.596423    -0.948371    -0.378681         0.540780
# 7       -0.920043       -0.596423     1.613382    -0.378681         0.540780
# 8        1.242228       -0.596423     0.698470    -0.378681        -1.849019
# 9       -0.920043        2.030322    -0.783097    -0.378681         0.540780
#
#    domain_with_copyright  domain_registration_length  domain_age  web_traffic  \
# 0               1.124450                    0.165911    0.841693    -0.392231
# 1              -0.889247                   -0.237121   -1.284089    -0.431489
# 2              -0.889247                   -0.460207   -0.756260    -0.431489
# 3               1.124450                   -0.446649   -0.877127    -0.431489
# 4              -0.889247                   -0.404743   -0.770725    -0.275487
# 5               1.124450                   -0.576063   -0.021413     2.421739
# 6              -0.889247                    0.262047    1.051282    -0.354145
# 7              -0.889247                   -0.606876   -1.305305    -0.431489
# 8               1.124450                   -0.524297    0.317079    -0.431299
# 9               1.124450                   -0.424464   -0.178283    -0.431489
#
#    google_index  page_rank  status  \
# 0     -1.073649   0.714605       1
# 1      0.931322  -1.260356       1
# 2      0.931322  -1.260356       1
# 3     -1.073649  -1.260356       0
# 4     -1.073649   0.319613       0
# 5      0.931322  -1.260356       1
# 6     -1.073649   0.319613       1
# 7      0.931322  -1.260356       1
# 8     -1.073649   0.714605       0
# 9     -1.073649  -0.470371       0
#
#                                                  url
# 0     http://www.progarchives.com/album.asp?id=61737
# 1  http://signin.eday.co.uk.ws.edayisapi.dllsign....
# 2  http://www.avevaconstruction.com/blesstool/ima...
# 3                              http://www.jp519.com/
# 4                       https://www.velocidrone.com/
# 5  https://support-appleld.com.secureupdate.duila...
# 6  https://www.authpro.com/auth/ubabankng/?action...
# 7  http://littlee.com.au/alibaba/login.alibaba.co...
# 8                http://www.tutorialspoint.com/dbms/
# 9                             http://www.domarada.sk

# %% [markdown]
# ## Getting Data
#
# Using pandas and numpy to get train, validation and testing data
#
# Also taking out the `URL` feature.

# %%
#Deleting URL as the features have been extracted from the URL
del df['url']

# %%
train, valid, test = np.split(df.sample(frac=1), [int(.6*len(df)), int(.8*len(df))])

trainX = train.drop(['status'],1)
trainY = train['status']

validX = valid.drop(['status'],1)
validY = valid['status']

testX = test.drop(['status'],1)
testY = test['status']

# %% [markdown]
# ## Fitting the Model

# %%
from random import random

# %%
#K-Nearest Neighbours
def KNN(trainXOrig, trainY, validX, k, isEuci):
    predictTp = []
    
    for tp in validX.values:
        #Copying the trainX so we don't use altered data sets
        trainX = trainXOrig.copy(deep=True)

        #Data Point - tp
        trainX = trainX.subtract(tp,axis=1)
        
        if (isEuci):
            #Euci
            trainX *= trainX

            #Get meanVec w/ Euci
            trainX['meanVec'] = np.sqrt(trainX.sum(axis=1).values)   
        else:
            #Get meanVec w/ Manhatan
            trainX['meanVec'] = np.abs(trainX.sum(axis=1).values)

        #Sort meanVec
        trainX.sort_values('meanVec',inplace=True)
        
        #Counting the ones that are phising and the ones that are not
        countPhish = 0
        countLegi = 0
        
        #Getting unique values (0, 1) and the amount of times they showed up for k
        countArr = np.unique(np.array([trainY[idx] for idx in trainX.index[:k]]), return_counts=True)
        
        #Adding to Counter
        if (len(countArr[0]) == 1):
            if (countArr[0][0] == 1):
                countPhish += countArr[1][0]
            else:
                countLegi += countArr[1][0]
        elif (countArr[0][0] == 0):
            countLegi += countArr[1][0]
            countPhish += countArr[1][1]
        else:
            countPhish += countArr[1][0]
            countLegi += countArr[1][1]
            
        #Checking the highest
        if (countPhish > countLegi):
            predictTp.append(1)
        elif(countLegi > countPhish):
            predictTp.append(0)
        else:
            if (random() > 0.5):
                predictTp.append(1)
            else:
                predictTp.append(0)
        
        
        
    return predictTp

# %%
def getConfusionMatrix(yActual, yObtained):
    if (len(yActual) != len(yObtained)):
        print("yActual and yObtained different lengths")
        return None
    
    phishMatch = 0
    phishNoMatch = 0
    legitMatch = 0
    legitNoMatch = 0
    
    for i in range(len(yActual)):
        yAct = yActual[i]
        yObt = yObtained[i]
        
        if (yAct == 1 and yObt == 1):
            phishMatch += 1
        if (yAct == 1 and yObt == 0):
            phishNoMatch += 1
        if (yAct == 0 and yObt == 0):
            legitMatch += 1
        if (yAct == 0 and yObt == 1):
            legitNoMatch += 1
    
    arr = np.array([[legitMatch,legitNoMatch],[phishNoMatch,phishMatch]])
    accu = (legitMatch + phishMatch)/sum([y for x in arr for y in x])
    
    df = pd.DataFrame(data=arr)
    
    df.columns = ["Legitimate", "Phishing"]
    df.index = ["Legitimate", "Phishing"]
    
    return df,accu

# %%
def showResults(cf, accu, k):
    print("\n")
    
    print("===========================")
    print("k is: " + str(k))
    print("===========================\n")
    
    print("===========================")
    print("Confusion Matrix\n")
    print(cf.head(2))
    print("\n=========================\n")
    
    print("===========================")
    print("Accuracy of: " + str(format(accu * 100,".5f")) + " %")
    print("===========================")
    
    print("\n")

# %%
def KNNwithOutput(trainXOrig, trainY, validX, validY, k, isEuci):
    yObtained = KNN(trainXOrig, trainY, validX, k, isEuci)
    
    confusionMat, accu = getConfusionMatrix(validY.values, yObtained)
    
    showResults(confusionMat, accu, k)
    
    return accu

# %% [markdown]
# ## Getting Optimal K - Eucilidean

# %%
optiK = None
accu = 0.0

kLst = [3,5,7,9,15,27,51,67,99,217,515,999]

for k in kLst:
    newAccu = KNNwithOutput(trainX, trainY, validX, validY, k, True)
    
    if (newAccu > accu):
        accu = newAccu
        optiK = k
# Out:
# ===========================
# k is: 3
# ===========================
#
# ===========================
# Confusion Matrix
#
#             Legitimate  Phishing
# Legitimate        1075        65
# Phishing            79      1077
#
# =========================
#
# ===========================
# Accuracy of: 93.72822 %
# ===========================
#
#
#
#
# ===========================
# k is: 5
# ===========================
#
# ===========================
# Confusion Matrix
#
#             Legitimate  Phishing
# Legitimate        1079        61
# Phishing            80      1076
#
# =========================
#
# ===========================
# Accuracy of: 93.85889 %
# ===========================
#
#
#
#
# ===========================
# k is: 7
# ===========================
#
# ===========================
# Confusion Matrix
#
#             Legitimate  Phishing
# Legitimate        1083        57
# Phishing           102      1054
#
# =========================
#
# ===========================
# Accuracy of: 93.07491 %
# ===========================
#
#
#
#
# ===========================
# k is: 9
# ===========================
#
# ===========================
# Confusion Matrix
#
#             Legitimate  Phishing
# Legitimate        1085        55
# Phishing            97      1059
#
# =========================
#
# ===========================
# Accuracy of: 93.37979 %
# ===========================
#
#
#
#
# ===========================
# k is: 15
# ===========================
#
# ===========================
# Confusion Matrix
#
#             Legitimate  Phishing
# Legitimate        1085        55
# Phishing           105      1051
#
# =========================
#
# ===========================
# Accuracy of: 93.03136 %
# ===========================
#
#
#
#
# ===========================
# k is: 27
# ===========================
#
# ===========================
# Confusion Matrix
#
#             Legitimate  Phishing
# Legitimate        1089        51
# Phishing           118      1038
#
# =========================
#
# ===========================
# Accuracy of: 92.63937 %
# ===========================
#
#
#
#
# ===========================
# k is: 51
# ===========================
#
# ===========================
# Confusion Matrix
#
#             Legitimate  Phishing
# Legitimate        1089        51
# Phishing           136      1020
#
# =========================
#
# ===========================
# Accuracy of: 91.85540 %
# ===========================
#
#
#
#
# ===========================
# k is: 67
# ===========================
#
# ===========================
# Confusion Matrix
#
#             Legitimate  Phishing
# Legitimate        1086        54
# Phishing           147      1009
#
# =========================
#
# ===========================
# Accuracy of: 91.24564 %
# ===========================
#
#
#
#
# ===========================
# k is: 99
# ===========================
#
# ===========================
# Confusion Matrix
#
#             Legitimate  Phishing
# Legitimate        1088        52
# Phishing           157       999
#
# =========================
#
# ===========================
# Accuracy of: 90.89721 %
# ===========================
#
#
#
#
# ===========================
# k is: 217
# ===========================
#
# ===========================
# Confusion Matrix
#
#             Legitimate  Phishing
# Legitimate        1073        67
# Phishing           210       946
#
# =========================
#
# ===========================
# Accuracy of: 87.93554 %
# ===========================
#
#
#
#
# ===========================
# k is: 515
# ===========================
#
# ===========================
# Confusion Matrix
#
#             Legitimate  Phishing
# Legitimate        1081        59
# Phishing           281       875
#
# =========================
#
# ===========================
# Accuracy of: 85.19164 %
# ===========================
#
#
#
#
# ===========================
# k is: 999
# ===========================
#
# ===========================
# Confusion Matrix
#
#             Legitimate  Phishing
# Legitimate        1099        41
# Phishing           425       731
#
# =========================
#
# ===========================
# Accuracy of: 79.70383 %
# ===========================

# %% [markdown]
# ### Optimal K - With Eucilidean

# %%
print("===========================")
print("Optimal k value is: " + str(optiK))
print("===========================")
# Out:
# ===========================
# Optimal k value is: 5
# ===========================

# %%
KNNwithOutput(trainX, trainY, testX, testY, optiK, True)
# Out:
# ===========================
# k is: 5
# ===========================
#
# ===========================
# Confusion Matrix
#
#             Legitimate  Phishing
# Legitimate        1112        43
# Phishing            73      1069
#
# =========================
#
# ===========================
# Accuracy of: 94.94993 %
# ===========================
# 0.9494993469743144
